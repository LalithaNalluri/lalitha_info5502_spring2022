# %% [markdown]
# ## The eighth Lab-assignment (04/07/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand how to conduct Sampling and Distributions. The data used in this lab assignment will contain salary data and other statistics for basketball players from the 2014-2015 NBA season. This data was collected from the following sports analytic sites: [Basketball Reference](http://www.basketball-reference.com) and [Spotrac](http://www.spotrac.com). The dataset of this assignment can be downloaded from github: https://github.com/unt-iialab/info5502-spring2022/tree/main/datasets/lab-assignment-8
#
# First, set up the tests and imports by running the cell below.

# %%
# Install the required package
# !pip install datascience
# Out:
# Requirement already satisfied: datascience in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (0.17.0)
# Requirement already satisfied: folium>=0.9.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (0.12.1.post1)
# Requirement already satisfied: sphinx in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (4.5.0)
# Requirement already satisfied: setuptools in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (62.0.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (3.5.1)
# Requirement already satisfied: pandas in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (1.4.0)
# Requirement already satisfied: scipy in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (1.7.3)
# Requirement already satisfied: numpy in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (1.22.3)
# Requirement already satisfied: ipython in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (8.0.1)
# Requirement already satisfied: plotly in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (5.6.0)
# Requirement already satisfied: branca in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (0.4.2)
# Requirement already satisfied: nbsphinx in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (0.8.8)
# Requirement already satisfied: pytest in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (7.1.1)
# Requirement already satisfied: coverage in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (6.3.2)
# Requirement already satisfied: coveralls in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (3.3.1)
# Requirement already satisfied: bokeh in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from datascience) (2.4.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.9.1->datascience) (3.0.3)
# Requirement already satisfied: requests in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from folium>=0.9.1->datascience) (2.27.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (9.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (4.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.0.0->datascience) (3.0.7)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from bokeh->datascience) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from bokeh->datascience) (6.1)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from bokeh->datascience) (4.0.1)
# Requirement already satisfied: docopt>=0.6.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from coveralls->datascience) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (5.1.1)
# Requirement already satisfied: colorama in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (3.0.24)
# Requirement already satisfied: backcall in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (0.18.1)
# Requirement already satisfied: pygments in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (2.11.2)
# Requirement already satisfied: matplotlib-inline in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (0.1.3)
# Requirement already satisfied: decorator in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (0.1.4)
# Requirement already satisfied: black in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from ipython->datascience) (21.12b0)
# Requirement already satisfied: nbconvert!=5.4 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbsphinx->datascience) (6.4.0)
# Requirement already satisfied: nbformat in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbsphinx->datascience) (5.1.3)
# Requirement already satisfied: docutils in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbsphinx->datascience) (0.17.1)
# Requirement already satisfied: babel>=1.3 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (2.9.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (2.0.0)
# Requirement already satisfied: imagesize in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (1.3.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (1.1.5)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (1.0.1)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (2.2.0)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (1.0.2)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (1.0.2)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (1.0.3)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from sphinx->datascience) (0.7.12)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pandas->datascience) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from plotly->datascience) (8.0.1)
# Requirement already satisfied: six in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from plotly->datascience) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pytest->datascience) (21.4.0)
# Requirement already satisfied: py>=1.8.2 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pytest->datascience) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pytest->datascience) (1.2.3)
# Requirement already satisfied: iniconfig in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pytest->datascience) (1.1.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pytest->datascience) (1.4.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from pytest->datascience) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->datascience) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.5.10)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.7.1)
# Requirement already satisfied: bleach in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (4.1.0)
# Requirement already satisfied: testpath in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbconvert!=5.4->nbsphinx->datascience) (4.9.1)
# Requirement already satisfied: ipython-genutils in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbformat->nbsphinx->datascience) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbformat->nbsphinx->datascience) (4.4.0)
# Requirement already satisfied: wcwidth in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from requests->folium>=0.9.1->datascience) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from requests->folium>=0.9.1->datascience) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from requests->folium>=0.9.1->datascience) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from requests->folium>=0.9.1->datascience) (2.0.12)
# Requirement already satisfied: click>=7.1.2 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from black->ipython->datascience) (8.0.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from black->ipython->datascience) (2.4.1)
# Requirement already satisfied: pathspec<1,>=0.9.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from black->ipython->datascience) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from black->ipython->datascience) (0.4.3)
# Requirement already satisfied: pure-eval in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->datascience) (0.2.2)
# Requirement already satisfied: executing in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->datascience) (0.8.2)
# Requirement already satisfied: asttokens in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->datascience) (2.0.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->nbsphinx->datascience) (0.18.1)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\lalit\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: nest-asyncio in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (1.5.4)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (7.1.2)
# Requirement already satisfied: webencodings in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from bleach->nbconvert!=5.4->nbsphinx->datascience) (0.5.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core->nbconvert!=5.4->nbsphinx->datascience) (303)
# Requirement already satisfied: pyzmq>=13 in c:\users\lalit\appdata\local\programs\python\python310\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert!=5.4->nbsphinx->datascience) (22.3.0)

# %%
# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# Run the cell below to load player and salary data that we will use for our sampling.

# %%
player_data = Table().read_table("player_data.csv")
salary_data = Table().read_table("salary_data.csv")
full_data = salary_data.join("PlayerName", player_data, "Name")

# The show method immediately displays the contents of a table. 
# This way, we can display the top of two tables using a single cell.
player_data.show(3)
salary_data.show(3)
full_data.show(3)
print(type(full_data))
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Name</th> <th>Age</th> <th>Team</th> <th>Games</th> <th>Rebounds</th> <th>Assists</th> <th>Steals</th> <th>Blocks</th> <th>Turnovers</th> <th>Points</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>James Harden </td> <td>25  </td> <td>HOU </td> <td>81   </td> <td>459     </td> <td>565    </td> <td>154   </td> <td>60    </td> <td>321      </td> <td>2217  </td>
#         </tr>
#         <tr>
#             <td>Chris Paul   </td> <td>29  </td> <td>LAC </td> <td>82   </td> <td>376     </td> <td>838    </td> <td>156   </td> <td>15    </td> <td>190      </td> <td>1564  </td>
#         </tr>
#         <tr>
#             <td>Stephen Curry</td> <td>26  </td> <td>GSW </td> <td>80   </td> <td>341     </td> <td>619    </td> <td>163   </td> <td>16    </td> <td>249      </td> <td>1900  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (489 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PlayerName</th> <th>Salary</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Kobe Bryant      </td> <td>23500000</td>
#         </tr>
#         <tr>
#             <td>Amar'e Stoudemire</td> <td>23410988</td>
#         </tr>
#         <tr>
#             <td>Joe Johnson      </td> <td>23180790</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (489 rows omitted)</p>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>PlayerName</th> <th>Salary</th> <th>Age</th> <th>Team</th> <th>Games</th> <th>Rebounds</th> <th>Assists</th> <th>Steals</th> <th>Blocks</th> <th>Turnovers</th> <th>Points</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>A.J. Price  </td> <td>62552  </td> <td>28  </td> <td>TOT </td> <td>26   </td> <td>32      </td> <td>46     </td> <td>7     </td> <td>0     </td> <td>14       </td> <td>133   </td>
#         </tr>
#         <tr>
#             <td>Aaron Brooks</td> <td>1145685</td> <td>30  </td> <td>CHI </td> <td>82   </td> <td>166     </td> <td>261    </td> <td>54    </td> <td>15    </td> <td>157      </td> <td>954   </td>
#         </tr>
#         <tr>
#             <td>Aaron Gordon</td> <td>3992040</td> <td>19  </td> <td>ORL </td> <td>47   </td> <td>169     </td> <td>33     </td> <td>21    </td> <td>22    </td> <td>38       </td> <td>243   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (489 rows omitted)</p>
# <class 'datascience.tables.Table'>

# %% [markdown]
# Rather than getting data on every player (as in the tables loaded above), imagine that we had gotten data on only a smaller subset of the players. For 492 players, it's not so unreasonable to expect to see all the data, but usually we aren't so lucky.
#
# If we want to make estimates about a certain numerical property of the population (known as a statistic, e.g. the mean or median), we may have to come up with these estimates based only on a smaller sample. Whether these estimates are useful or not often depends on how the sample was gathered. We have prepared some example sample datasets to see how they compare to the full NBA dataset. Later we'll ask you to create your own samples to see how they behave.

# %% [markdown]
# To save typing and increase the clarity of your code, we will package the analysis code into a few functions. This will be useful in the rest of the lab as we will repeatedly need to create histograms and collect summary statistics from that data.

# %% [markdown]
# We've defined the histograms function below, which takes a table with columns Age and Salary and draws a histogram for each one. It uses bin widths of 1 year for Age and $1,000,000 for Salary.

# %%
def histograms(t):
    ages = t.column('Age')
    salaries = t.column('Salary')/1000000
    t1 = t.drop('Salary').with_column('Salary', salaries)
    age_bins = np.arange(min(ages), max(ages) + 2, 1) 
    salary_bins = np.arange(min(salaries), max(salaries) + 1, 1)
    t1.hist('Age', bins=age_bins, unit='year')
    plt.title('Age distribution')
    t1.hist('Salary', bins=salary_bins, unit='million dollars')
    plt.title('Salary distribution') 
    
histograms(full_data)
print('Two histograms should be displayed below')
# Out:
# Two histograms should be displayed below

# %% [markdown]
# ### Question 1 (10 points)
#
# Create a function called compute_statistics that takes a table containing ages and salaries and:
#
# (1) Draws a histogram of ages
#
# (2) Draws a histogram of salaries
#
# (3) Returns a two-element array containing the average age and average salary (in that order)
#
#
# You can call the histograms function to draw the histograms!
#
# Note: More charts will be displayed when running the test cell. Please feel free to ignore the charts.

# %%
### You code here

def compute_statistics(age_and_salary_data):
    age = age_and_salary_data['Age'].mean()
    salary = age_and_salary_data['Salary'].mean()
    histograms(age_and_salary_data)
    return age,salary
    

full_stats = compute_statistics(full_data)
full_stats
# Out:
# (26.536585365853657, 4269775.766260163)

# %%
# TEST
stats = compute_statistics(full_data)
plt.close()
plt.close()
round(float(stats[0]), 2) == 26.54
# Out:
# True

# %%
# TEST
stats = compute_statistics(full_data)
plt.close()
plt.close()
round(float(stats[1]), 2) == 4269775.77
# Out:
# True

# %% [markdown]
# ### Question 2 (10 points) Convenience sampling
#
# One sampling methodology, which is generally a bad idea, is to choose players who are somehow convenient to sample. For example, you might choose players from one team who are near your house, since it's easier to survey them. This is called, somewhat pejoratively, convenience sampling.
#
# Suppose you survey only relatively new players with ages less than 22. (The more experienced players didn't bother to answer your surveys about their salaries.)
#
# Assign `convenience_sample` to a subset of `full_data` that contains only the rows for players under the age of 22.

# %%
### You code here:
#full_data=pd.DataFrame(full_data)
convenience_sample = full_data.where("Age", are.below(22))
convenience_sample
# Out:
# PlayerName      | Salary  | Age  | Team | Games | Rebounds | Assists | Steals | Blocks | Turnovers | Points
# Aaron Gordon    | 3992040 | 19   | ORL  | 47    | 169      | 33      | 21     | 22     | 38        | 243
# Alex Len        | 3649920 | 21   | PHO  | 69    | 454      | 32      | 34     | 105    | 74        | 432
# Andre Drummond  | 2568360 | 21   | DET  | 82    | 1104     | 55      | 73     | 153    | 120       | 1130
# Andrew Wiggins  | 5510640 | 19   | MIN  | 82    | 374      | 170     | 86     | 50     | 177       | 1387
# Anthony Bennett | 5563920 | 21   | MIN  | 57    | 216      | 48      | 27     | 16     | 36        | 298
# Anthony Davis   | 5607240 | 21   | NOP  | 68    | 696      | 149     | 100    | 200    | 95        | 1656
# Archie Goodwin  | 1112280 | 20   | PHO  | 41    | 74       | 44      | 18     | 9      | 48        | 231
# Ben McLemore    | 3026280 | 21   | SAC  | 82    | 241      | 140     | 77     | 19     | 138       | 996
# Bradley Beal    | 4505280 | 21   | WAS  | 63    | 241      | 194     | 76     | 18     | 123       | 962
# Bruno Caboclo   | 1458360 | 19   | TOR  | 8     | 2        | 0       | 0      | 1      | 4         | 10
# ... (34 rows omitted)

# %%
# TEST
convenience_sample.num_columns == 11
# Out:
# True

# %%
# TEST
convenience_sample.num_rows == 44
# Out:
# True

# %% [markdown]
# ### Question 3 (10 points)
#
# Assign convenience_stats to an array of the average age and average salary of your convenience sample, using the compute_statistics function. Since they're computed on a sample, these are called sample averages.

# %%
#convenience_stats =  convenience_sample.pivot('Age', 'Salary',values=['Age','Salary'], collect = np.mean)
   # salary = age_and_salary_data[].mean()
#convenience_stats
#convenience_stats=np.mean(convenience_sample['Age']),np.mean(convenience_sample['Salary'])
convenience_stats=compute_statistics(convenience_sample)
convenience_stats
# Out:
# (20.363636363636363, 2383533.8181818184)

# %%
# TEST
len(convenience_stats) == 2
# Out:
# True

# %%
# TEST 
round(float(convenience_stats[0]), 2) == 20.36
# Out:
# True

# %%
# TEST
round(float(convenience_stats[1]), 2) == 2383533.82
# Out:
# True

# %% [markdown]
# Next, we'll compare the convenience sample salaries with the full data salaries in a single histogram. To do that, we'll need to use the bin_column option of the hist method, which indicates that all columns are counts of the bins in a particular column. The following cell does not require any changes; just run it.

# %%
def compare_salaries(first, second, first_title, second_title):
    """Compare the salaries in two tables."""
    first_salary_in_millions = first.column('Salary')/1000000
    second_salary_in_millions = second.column('Salary')/1000000
    first_tbl_millions = first.drop('Salary').with_column('Salary', first_salary_in_millions)
    second_tbl_millions = second.drop('Salary').with_column('Salary', second_salary_in_millions)
    max_salary = max(np.append(first_tbl_millions.column('Salary'), second_tbl_millions.column('Salary')))
    bins = np.arange(0, max_salary+1, 1)
    first_binned = first_tbl_millions.bin('Salary', bins=bins).relabeled(1, first_title)
    second_binned = second_tbl_millions.bin('Salary', bins=bins).relabeled(1, second_title)
    first_binned.join('bin', second_binned).hist(bin_column='bin', unit='million dollars')
    plt.title('Salaries for all players and convenience sample')

compare_salaries(full_data, convenience_sample, 'All Players', 'Convenience Sample')

# %% [markdown]
# ### Question 4 (10 points)
# Does the convenience sample give us an accurate picture of the salary of the full population? Would you expect it to, in general? Before you move on, write a short answer in English below. You can refer to the statistics calculated above or perform your own analysis.

# %%
### Please write your answer here (no code required)

"""
Answer: 
since we only considered players whose age is less than 22,
Convienece sample doesn't give accurate picture of salary of full population as it is clearly displyed in above graph.


"""
# Out:
# '\nAnswer: \n\n\n\n'

# %% [markdown]
# ### Simple random sampling
# A more justifiable approach is to sample uniformly at random from the players.  In a **simple random sample (SRS) without replacement**, we ensure that each player is selected at most once. Imagine writing down each player's name on a card, putting the cards in an box, and shuffling the box.  Then, pull out cards one by one and set them aside, stopping when the specified sample size is reached.

# %% [markdown]
# ### Producing simple random samples
# Sometimes, it’s useful to take random samples even when we have the data for the whole population. It helps us understand sampling accuracy.
#
# ### `sample`
#
# The table method `sample` produces a random sample from the table. By default, it draws at random **with replacement** from the rows of a table. It takes in the sample size as its argument and returns a **table** with only the rows that were selected.
#
# Run the cell below to see an example call to `sample()` with a sample size of 5, with replacement.

# %%
# Just run this cell

salary_data.sample(5)
# Out:
# PlayerName     | Salary
# Tiago Splitter | 9250000
# Tobias Harris  | 2380594
# Rodney Stuckey | 1227985
# Bernard James  | 915243
# JaMychal Green | 134295

# %% [markdown]
# The optional argument with_replacement=False can be passed through sample() to specify that the sample should be drawn without replacement.
#
# Run the cell below to see an example call to sample() with a sample size of 5, without replacement.

# %%
# Just run this cell

salary_data.sample(5, with_replacement=False)
# Out:
# PlayerName    | Salary
# Will Cherry   | 507336
# Stephen Curry | 10629213
# Norris Cole   | 2038206
# Xavier Henry  | 1082000
# Chris Johnson | 948163

# %% [markdown]
# ### Question 5 (10 points)
# Produce a simple random sample of size 44 from `full_data`. Run your analysis on it again.  Run the cell a few times to see how the histograms and statistics change across different samples.

# %%
import random
my_small_srswor_data = full_data.sample(44)
my_small_srswor_data
#histograms(my_small_srswor_data)
my_small_stats = compute_statistics(my_small_srswor_data)
my_small_stats
# Out:
# (27.272727272727273, 3285247.7045454546)

# %% [markdown]
# Before you move on, write a short answer for the following questions in English:
#
# (1) How much does the average age change across samples?
#
# (2) What about average salary?

# %%
### Please write your answer here (no code required)

"""
Answer: 

The rate of change in age is 1 to 0.1
the change for Salary is high 

"""
# Out:
# '\nAnswer: \n\n\n\n'

# %% [markdown]
# ### Question 6 (5 extra points)
# As in the previous question, analyze several simple random samples of size 100 from `full_data`.

# %%
my_large_srswor_data = full_data.sample(100)
my_large_stats = compute_statistics(my_large_srswor_data)
my_large_stats
# Out:
# (27.52, 4773183.57)

# %% [markdown]
# Answer the following questions in English:
#
# (1) Do the histogram shapes seem to change more or less across samples of 100 than across samples of size 44?
#
# (2) Are the sample averages and histograms closer to their true values/shape for age or for salary? What did you expect to see?

# %%
### Please write your answer here (no code required)

"""
Answer: 

1. Histogram change seems to be less across samples of 100 than across samples of 44
2.the sample averages and histograms closer to their true values/shape for age or for salary

"""
